93,Ядра орехов фундук жареный «Дары природы»,279,150,г,20
94,Джем клубничный «Махеевъ»,99,300,г,23
95,Мука «Рязаночка» для жидкого теста,59,1,кг,16
96,Яйцо «Праксис» С1,69,8,шт,25
97,Сахар-песок «Еврозлак»,109,750,г,23
98,Лук репчатый Россия,69,1,кг,26
99,Лук зеленый Россия,35,50,г,26
100,Чеснок Киргизия,29,2,шт,26
101,Укроп Россия,35,50,г,26
102,Мякоть мраморной говядины охлажденная «Праймбиф»,499,500,г,27
103,Говяжья мякоть лопатки Black Angus «Мираторг» охлаждённая,569,800,г,27
104,Капуста молодая Россия,49,1,шт,26
105,Свекла Россия,24,500,г,26
106,Картофель ранний Азербайджан,79,1,кг,26
107,Морковь Россия,69,1,кг,26
108,Сметана «Село Зелёное» 20%,59,180,7,25
109,Соус Barilla томатный Болоньезе,339,400,г,21
110,Томатная паста «Помидорка» в стеклянной банке,75,250,мл,
111,Пюре Cirio Passata томатное,139,500,г,21
112,Заправка для борща Maggi Свекольно-томатная,79,250,г,21
113,Жареный миндаль «Семушка»,359,150,г,20
"""

f = StringIO(raw)
reader = csv.reader(f, delimiter=',')
DB = {}
for row in reader:
    if not len(row):
        continue
    
    DB[row[0]] = row[1]
    
DB
# Out:
# {'id': 'name',
#  '1': 'Сок Jumex апельсин без сахара',
#  '2': 'Evervess Тоник напиток сильногазированный',
#  '3': 'Газированный напиток Pepsi',
#  '4': 'Sprite классический',
#  '5': 'Сок Rich яблоко-киви-шпинат',
#  '6': 'Багет',
#  '7': "Чипсы Lay's картофельные Лобстер рифленые",
#  '8': 'Чипсы San Carlo Piu Gusto лайм и розовый перец',
#  '9': 'Чипсы картофельные «Пакет картошки» с трюфелем',
#  '10': 'Хлеб «Бородинский»',
#  '11': 'Хлеб «Мультизлаковый»',
#  '12': 'Хлеб чесночный «Братья Караваевы»',
#  '13': 'Мини-чиабата «Братья Караваевы»',
#  '14': 'Хлеб «Цельнозерновой» из смеси ржаной и пшеничной муки «Рижский хлеб»',
#  '15': 'Сосиски «Докторские» «Клинский»',
#  '16': '«ВкусВилл» «Люкс» сосиски куриные',
#  '17': 'Сосиски «Окраина» «Кроха»',
#  '18': 'Сосиски сливочные «Дымов»',
#  '19': 'Колбаса варёная «Клинский мясокомбинат» докторская нарезка',
#  '20': 'Колбаса варёная «Окраина» с натуральным молоком',
#  '21': 'Колбаса вареная «ВкусВилл» нарезка',
# ...

# %%
import json

raw_json = """
[
  {
    "id": 1,
    "amount": 2
  },
  {
    "id": 5,
    "amount": 6
  },
  {
    "id": 6,
    "amount": 13
  },
  {
    "id": 13,
    "amount": 10
  },
  {
    "id": 14,
    "amount": 5
  },
  {
    "id": 17,
    "amount": 3
  },
  {
    "id": 18,
    "amount": 3
  },
  {
    "id": 140,
    "amount": 2
  }
]
"""

data = json.loads(raw_json)
data
# Out:
# [{'id': 1, 'amount': 2},
#  {'id': 5, 'amount': 6},
#  {'id': 6, 'amount': 13},
#  {'id': 13, 'amount': 10},
#  {'id': 14, 'amount': 5},
#  {'id': 17, 'amount': 3},
#  {'id': 18, 'amount': 3},
#  {'id': 19, 'amount': 10},
#  {'id': 21, 'amount': 5},
#  {'id': 25, 'amount': 10},
#  {'id': 26, 'amount': 3},
#  {'id': 30, 'amount': 4},
#  {'id': 31, 'amount': 8},
#  {'id': 32, 'amount': 3},
#  {'id': 33, 'amount': 13},
#  {'id': 37, 'amount': 8},
#  {'id': 38, 'amount': 6},
#  {'id': 39, 'amount': 1},
#  {'id': 40, 'amount': 8},
#  {'id': 42, 'amount': 9},
#  {'id': 43, 'amount': 1},
#  {'id': 44, 'amount': 8},
#  {'id': 47, 'amount': 6},
#  {'id': 49, 'amount': 2},
#  {'id': 50, 'amount': 6},
#  {'id': 53, 'amount': 12},
#  {'id': 55, 'amount': 8},
#  {'id': 57, 'amount': 7},
#  {'id': 60, 'amount': 11},
#  {'id': 61, 'amount': 11},
#  {'id': 62, 'amount': 11},
#  {'id': 63, 'amount': 8},
#  {'id': 66, 'amount': 7},
#  {'id': 69, 'amount': 5},
#  {'id': 70, 'amount': 10},
# ...

# %%
result = []

for obj in data:
    new_obj = {}
    new_obj['id'] = obj['id']
    new_obj['amount'] = obj['amount']
    if f'{obj["id"]}' not in DB:
        continue
    
    new_obj['productName'] = DB[f'{obj["id"]}']
    result.append(new_obj)
    
result
# Out:
# [{'id': 1, 'amount': 2, 'productName': 'Сок Jumex апельсин без сахара'},
#  {'id': 5, 'amount': 6, 'productName': 'Сок Rich яблоко-киви-шпинат'},
#  {'id': 6, 'amount': 13, 'productName': 'Багет'},
#  {'id': 13, 'amount': 10, 'productName': 'Мини-чиабата «Братья Караваевы»'},
#  {'id': 14,
#   'amount': 5,
#   'productName': 'Хлеб «Цельнозерновой» из смеси ржаной и пшеничной муки «Рижский хлеб»'},
#  {'id': 17, 'amount': 3, 'productName': 'Сосиски «Окраина» «Кроха»'},
#  {'id': 18, 'amount': 3, 'productName': 'Сосиски сливочные «Дымов»'},
#  {'id': 19,
#   'amount': 10,
#   'productName': 'Колбаса варёная «Клинский мясокомбинат» докторская нарезка'},
#  {'id': 21, 'amount': 5, 'productName': 'Колбаса вареная «ВкусВилл» нарезка'},
#  {'id': 25,
#   'amount': 10,
#   'productName': 'Салфетки влажные детские Aqua Pure Pampers'},
#  {'id': 26,
#   'amount': 3,
#   'productName': 'Спрей от комаров Gardex Baby для детей от 2 лет'},
# ...

# %%
import json

json.dumps({"is_false": False, "is_true":True})
# Out:
# '{"is_false": false, "is_true": true}'
